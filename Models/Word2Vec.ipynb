# %% [markdown]
# Word to vect from scratch: https://towardsdatascience.com/implementing-word2vec-in-pytorch-from-the-ground-up-c7fe5bf99889
# Word2Vec paper: https://arxiv.org/pdf/1301.3781

# %%
import json
import numpy as np

# %%
# Read evidence
with open('../data/evidence.json', 'r') as f:
    evidence = json.load(f)
evidence = [str.lower(j) for i,j in evidence.items()]

# %%
# MODIFY
from dataclasses import dataclass, field
import torch
import torch.nn as nn
     

@dataclass(repr=True)
class Word2VecParams:

    # skipgram parameters
    MIN_FREQ = 50               # Minimum occurency of words
    SKIPGRAM_N_WORDS = 8        # n-grams to consider the tager (Bidirectional)
    T = 85                      # words with frequency in the 85th percentile will have a small probability  of being subsampled
    NEG_SAMPLES = 50
    NS_ARRAY_LEN = 5_000_000
    SPECIALS = ""               # Excluded words
    TOKENIZER = 'basic_english'

    # network parameters
    BATCH_SIZE = 100
    EMBED_DIM = 300
    EMBED_MAX_NORM = None
    N_EPOCHS = 5
    DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu") 
    CRITERION = nn.BCEWithLogitsLoss()
     

params = Word2VecParams()

# %%
class Vocab:
    def __init__(self, list, specials):
        self.stoi = {v[0]:(k, v[1]) for k, v in enumerate(list)}
        self.itos = {k:(v[0], v[1]) for k, v in enumerate(list)}
        self._specials = specials[0]
        self.total_tokens = np.nansum(
            [f for _, (_, f) in self.stoi.items()]
            , dtype=int)

    def __len__(self):
        return len(self.stoi) - 1

    # Return word from counter dict
    def get_index(self, word):
        if isinstance(word, str):
            if word in self.stoi: 
                return self.stoi.get(word)[0]
            else:
                return self.stoi.get(self._specials)[0]
        elif isinstance(word, list):
            res = []
            for w in word:
                if w in self.stoi: 
                    res.append(self.stoi.get(w)[0])
                else:
                    res.append(self.stoi.get(self._specials)[0])
            return res
        else:
            raise ValueError(
                f"Word {word} is not a string or a list of strings."
                )


    def get_freq(self, word):
        if isinstance(word, str):
            if word in self.stoi: 
                return self.stoi.get(word)[1]
            else:
                return self.stoi.get(self._specials)[1]
        elif isinstance(word, list):
            res = []
            for w in word:
                if w in self.stoi:
                    res.append(self.stoi.get(w)[1])
                else:
                    res.append(self.stoi.get(self._specials)[1])
            return res
        else:
            raise ValueError(
                f"Word {word} is not a string or a list of strings."
                )
    

    def lookup_token(self, token):
        if isinstance(token, (int, np.int64)):
            if token in self.itos:
                return self.itos.get(token)[0]
            else:
                raise ValueError(f"Token {token} not in vocabulary")
        elif isinstance(token, list):
            res = []
            for t in token:
                if t in self.itos:
                    res.append(self.itos.get(token)[0])
                else:
                    raise ValueError(f"Token {t} is not a valid index.")
            return res

# %%
def vocab(ordered_dict:dict, min_freq: int = 1, specials: str = '<unk>'):
    tokens = []
    # Save room for special tokens
    for token, freq in ordered_dict.items():
        if freq >= min_freq:
            tokens.append((token, freq))

    specials = (specials, np.nan)
    tokens[0] = specials

    return Vocab(tokens, specials)

# %%
from collections import Counter, OrderedDict
def build_vocab(
        iterator,                   # Training set
        tokenizer,                  # English tokenizer
        params: Word2VecParams,     # Instanciated parameters
        max_tokens = None,
    ):

    # Fill counter with filtered tokens
    counter = Counter()
    for tokens in yield_tokens(iterator, tokenizer):
        counter.update(tokens)

    # First sort by descending frequency, then lexicographically
    sorted_by_freq_tuples = sorted(
        counter.items(), key=lambda x: (-x[1], x[0])
        )

    ordered_dict = OrderedDict(sorted_by_freq_tuples)

    word_vocab = vocab(
        ordered_dict, min_freq=params.MIN_FREQ, specials=params.SPECIALS
        )
    return word_vocab

# %%
from torchtext.data import get_tokenizer
import re

# Parameters
tokenizer = get_tokenizer("basic_english")
MIN_FREQ = 50 
SPECIALS = "<unk>"

# Function to filter text
def filter_tokens(iterator, tokenizer):
    r = re.compile('[a-z1-9]')      # Only numbers and letters
    for text in iterator:
        res = tokenizer(text)
        res = list(filter(r.match, res))
        yield res

# Fill counter with filtered tokens
counter = Counter()
for tokens in filter_tokens(evidence[:100000], tokenizer=tokenizer):
    counter.update(tokens)

# Sort lexicographically
word_vocab = vocab(counter, min_freq=MIN_FREQ, specials=SPECIALS)
# Out:
# /Users/andresg/Documents/Semester_3/Natural Language Processing/COMP90042_NLP_Project/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# First sort by descending frequency, then lexicographically
sorted_by_freq_tuples = sorted(counter.items(), key=lambda x: (-x[1], x[0]))

# %%
word_vocab.stoi
# Out:
# {'<unk>': (0, nan),
#  'english': (1, 1075),
#  'and': (2, 56892),
#  'agricultural': (3, 126),
#  'scientist': (4, 95),
#  'began': (5, 618),
#  'his': (6, 7236),
#  'professional': (7, 883),
#  'career': (8, 772),
#  'at': (9, 10288),
#  'the': (10, 137026),
#  'age': (11, 484),
#  'of': (12, 71072),
#  '16': (13, 619),
#  'eventually': (14, 222),
#  'moving': (15, 127),
#  'to': (16, 30629),
#  'new': (17, 3524),
#  'york': (18, 1003),
#  'city': (19, 2098),
#  'in': (20, 62470),
#  '1977': (21, 279),
#  'cambridge': (22, 136),
#  'by': (23, 15433),
#  'francis': (24, 109),
#  'born': (25, 4337),
#  'october': (26, 1209),
#  '20': (27, 731),
#  '1936': (28, 161),
#  'was': (29, 25498),
#  'a': (30, 46819),
#  'ice': (31, 466),
#  'hockey': (32, 424),
#  'player': (33, 1000),
#  'who': (34, 3668),
#  'played': (35, 1758),
#  '40': (36, 232),
#  'games': (37, 875),
#  'national': (38, 2603),
#  'league': (39, 1568),
#  'he': (40, 11619),
#  'function': (41, 141),
#  'how': (42, 276),
#  'modified': (43, 55),
#  'release': (44, 428),
#  'with': (45, 11287),
#  'peak': (46, 171),
#  'minimum': (47, 50),
#  'pressure': (48, 131),
#  '28': (49, 485),
#  'florence': (50, 54),
#  'storm': (51, 108),
#  '1994': (52, 414),
#  'atlantic': (53, 175),
#  'hurricane': (54, 55),
#  'season': (55, 1794),
#  'is': (56, 32587),
#  'currently': (57, 827),
#  'professor': (58, 471),
#  'piano': (59, 100),
#  'university': (60, 2152),
#  'wisconsin': (61, 172),
#  'since': (62, 1418),
#  'august': (63, 1153),
#  '2000': (64, 584),
#  'addition': (65, 307),
#  'known': (66, 2869),
#  'black': (67, 459),
#  'extinction': (68, 54),
#  'events': (69, 462),
#  'may': (70, 2225),
#  'occur': (71, 89),
#  'an': (72, 9586),
#  'additional': (73, 179),
#  'problem': (74, 98),
#  'sir': (75, 240),
#  'able': (76, 153),
#  'hold': (77, 108),
#  'her': (78, 2054),
#  'off': (79, 352),
#  'for': (80, 15733),
#  'some': (81, 1453),
#  'five': (82, 596),
#  'hours': (83, 142),
#  'until': (84, 1291),
#  'suffered': (85, 75),
#  'severe': (86, 61),
#  'that': (87, 7795),
#  'almost': (88, 223),
#  'killed': (89, 194),
#  'him': (90, 748),
#  'russian': (91, 446),
#  '24': (92, 493),
#  'february': (93, 975),
#  '1981': (94, 272),
#  'folk': (95, 122),
#  'musician': (96, 217),
#  'go': (97, 162),
#  'back': (98, 488),
#  'original': (99, 566),
#  'paper': (100, 176),
#  'e': (101, 523),
#  'le': (102, 141),
#  'italian': (103, 471),
#  'association': (104, 693),
#  'against': (105, 896),
#  'current': (106, 453),
#  'individual': (107, 264),
#  'world': (108, 2449),
#  'champion': (109, 291),
#  'constant': (110, 60),
#  'weight': (111, 69),
#  'september': (112, 1216),
#  '2005': (113, 697),
#  'forced': (114, 115),
#  'from': (115, 10752),
#  'case': (116, 290),
#  'brought': (117, 162),
#  'police': (118, 284),
#  'commissioner': (119, 79),
#  '1971': (120, 296),
#  'became': (121, 1225),
#  'cause': (122, 140),
#  'war': (123, 1360),
#  'possibly': (124, 98),
#  'single': (125, 886),
#  'most': (126, 1902),
#  'important': (127, 446),
#  'event': (128, 597),
#  's': (129, 11499),
#  '7': (130, 888),
#  'series': (131, 1696),
#  'largest': (132, 471),
#  'cast': (133, 118),
#  'when': (134, 1767),
#  'employees': (135, 72),
#  'on': (136, 14715),
#  'something': (137, 63),
#  'their': (138, 2971),
#  'computers': (139, 50),
#  'get': (140, 135),
#  'access': (141, 207),
#  'best': (142, 1046),
#  'as': (143, 16121),
#  'author': (144, 436),
#  'prize': (145, 207),
#  'oil': (146, 283),
#  'money': (147, 168),
#  'power': (148, 687),
#  '1991': (149, 398),
#  'energy': (150, 659),
#  'security': (151, 204),
#  'modern': (152, 426),
#  '2011': (153, 968),
#  'your': (154, 103),
#  'operating': (155, 153),
#  'system': (156, 903),
#  'distribution': (157, 142),
#  'pro': (158, 90),
#  'or': (159, 5022),
#  'higher': (160, 231),
#  'types': (161, 136),
#  'formally': (162, 77),
#  'contact': (163, 64),
#  'movement': (164, 304),
#  'mainly': (165, 251),
#  'academic': (166, 200),
#  'late': (167, 559),
#  'compilation': (168, 114),
#  'other': (169, 2300),
#  'commune': (170, 272),
#  'march': (171, 1257),
#  '2012': (172, 889),
#  'it': (173, 11623),
#  'one': (174, 3864),
#  'were': (175, 3792),
#  'people': (176, 1198),
#  'live': (177, 471),
#  'often': (178, 626),
#  'have': (179, 2702),
#  'no': (180, 1035),
#  'education': (181, 555),
#  'healthcare': (182, 51),
#  'urban': (183, 206),
#  'economy': (184, 126),
#  'search': (185, 86),
#  'engine': (186, 156),
#  'marketing': (187, 79),
#  'voice': (188, 173),
#  'actor': (189, 461),
#  'did': (190, 483),
#  'not': (191, 2353),
#  'chart': (192, 301),
#  'united': (193, 2804),
#  'states': (194, 2395),
#  'despite': (195, 221),
#  'receiving': (196, 79),
#  'several': (197, 1160),
#  'markets': (198, 76),
#  'connect': (199, 50),
#  'factors': (200, 92),
#  'lead': (201, 381),
#  'protein': (202, 102),
#  'species': (203, 1414),
#  'beetle': (204, 129),
#  'family': (205, 1801),
#  'cerambycidae': (206, 88),
#  'only': (207, 1523),
#  'genus': (208, 618),
#  'i': (209, 999),
#  'never': (210, 214),
#  'return': (211, 181),
#  'available': (212, 325),
#  'internet': (213, 116),
#  'publisher': (214, 95),
#  '2006': (215, 1061),
#  'census': (216, 743),
#  'its': (217, 4283),
#  'population': (218, 1299),
#  '27': (219, 488),
#  '4': (220, 1170),
#  'families': (221, 342),
#  'area': (222, 1563),
#  'mathematical': (223, 72),
#  'computer': (224, 248),
#  'science': (225, 552),
#  'type': (226, 365),
#  'theory': (227, 220),
#  'feature': (228, 252),
#  'formal': (229, 68),
#  'language': (230, 519),
#  'old': (231, 450),
#  'ones': (232, 57),
#  'christopher': (233, 92),
#  'paul': (234, 324),
#  'artistic': (235, 82),
#  'director': (236, 658),
#  'music': (237, 1402),
#  'theatre': (238, 278),
#  'american': (239, 2930),
#  'drama': (240, 304),
#  'group': (241, 1297),
#  'europe': (242, 420),
#  'spain': (243, 303),
#  'men': (244, 589),
#  'volleyball': (245, 93),
#  'team': (246, 1663),
#  'bridge': (247, 302),
#  'village': (248, 1769),
#  'china': (249, 547),
#  'many': (250, 1402),
#  'reports': (251, 118),
#  'influence': (252, 157),
#  'policy': (253, 255),
#  'are': (254, 5741),
#  'instrumental': (255, 59),
#  'research': (256, 709),
#  'programs': (257, 267),
#  'others': (258, 356),
#  'provide': (259, 259),
#  'independent': (260, 400),
#  'program': (261, 497),
#  'reviews': (262, 114),
#  'song': (263, 1133),
#  'written': (264, 694),
#  '1975': (265, 299),
#  'ship': (266, 246),
#  'started': (267, 447),
#  'can': (268, 1554),
#  'down': (269, 423),
#  'grass': (270, 57),
#  'but': (271, 2493),
#  'has': (272, 5003),
#  'roots': (273, 57),
#  'underground': (274, 107),
#  'allow': (275, 120),
#  'grow': (276, 65),
#  'jack': (277, 137),
#  'also': (278, 5515),
#  'action': (279, 281),
#  'sport': (280, 150),
#  'involves': (281, 75),
#  'covered': (282, 139),
#  'snow': (283, 60),
#  'administrative': (284, 463),
#  'district': (285, 2852),
#  'gmina': (286, 303),
#  'within': (287, 1008),
#  'county': (288, 2619),
#  'voivodeship': (289, 339),
#  'poland': (290, 521),
#  'results': (291, 196),
#  '2008': (292, 896),
#  'little': (293, 297),
#  'determined': (294, 65),
#  'between': (295, 1904),
#  '15': (296, 676),
#  'south': (297, 2027),
#  'pennsylvania': (298, 302),
#  'being': (299, 1173),
#  'law': (300, 659),
#  'republic': (301, 486),
#  'basic': (302, 97),
#  'adopted': (303, 118),
#  'april': (304, 1132),
#  '1990': (305, 367),
#  'seventh': (306, 117),
#  'congress': (307, 228),
#  'signed': (308, 259),
#  'president': (309, 808),
#  'motorcycle': (310, 55),
#  'production': (311, 518),
#  'fall': (312, 152),
#  'due': (313, 644),
#  'cars': (314, 129),
#  'decided': (315, 143),
#  'light': (316, 340),
#  'sector': (317, 85),
#  'creating': (318, 106),
#  'models': (319, 126),
#  'engines': (320, 76),
#  'built': (321, 882),
#  '1922': (322, 141),
#  '1932': (323, 162),
#  'house': (324, 1255),
#  'army': (325, 631),
#  'medical': (326, 286),
#  'school': (327, 2165),
#  'which': (328, 5475),
#  'center': (329, 665),
#  '1923': (330, 139),
#  'under': (331, 1405),
#  'name': (332, 1763),
#  'department': (333, 637),
#  'service': (334, 710),
#  'combined': (335, 156),
#  'walter': (336, 114),
#  'general': (337, 855),
#  'hospital': (338, 252),
#  'european': (339, 530),
#  'sent': (340, 155),
#  'deep': (341, 124),
#  'into': (342, 1806),
#  'interior': (343, 77),
#  'land': (344, 501),
#  'large': (345, 672),
#  'desert': (346, 79),
#  'historical': (347, 285),
#  'western': (348, 718),
#  'film': (349, 2235),
#  'had': (350, 2563),
#  'fox': (351, 88),
#  'this': (352, 3964),
#  'musical': (353, 312),
#  'based': (354, 1179),
#  'established': (355, 628),
#  'popular': (356, 459),
#  'opera': (357, 215),
#  'would': (358, 1022),
#  'be': (359, 3718),
#  'success': (360, 254),
#  'proved': (361, 54),
#  'true': (362, 106),
#  'key': (363, 173),
#  'products': (364, 234),
#  'including': (365, 1381),
#  'registered': (366, 95),
#  'eu': (367, 52),
#  'us': (368, 448),
#  'michael': (369, 330),
#  'block': (370, 130),
#  'january': (371, 1207),
#  '1940': (372, 209),
#  'former': (373, 1456),
#  'footballer': (374, 637),
#  'right': (375, 297),
#  'even': (376, 317),
#  'though': (377, 337),
#  'languages': (378, 176),
#  'spoken': (379, 82),
#  'island': (380, 813),
#  'young': (381, 375),
#  'artists': (382, 241),
#  'representing': (383, 132),
#  'always': (384, 116),
#  'chosen': (385, 93),
#  'grant': (386, 111),
#  'them': (387, 680),
#  'better': (388, 199),
#  'band': (389, 1150),
#  'made': (390, 1278),
#  'hit': (391, 251),
#  'recording': (392, 229),
#  'vocal': (393, 62),
#  'entitled': (394, 96),
#  'what': (395, 350),
#  'she': (396, 2621),
#  'daughter': (397, 258),
#  'greek': (398, 312),
#  'king': (399, 581),
#  'princess': (400, 81),
#  'see': (401, 421),
#  'egypt': (402, 79),
#  'ancient': (403, 224),
#  'source': (404, 228),
#  'suggests': (405, 53),
#  'water': (406, 817),
#  'renamed': (407, 165),
#  'week': (408, 191),
#  'working': (409, 346),
#  'support': (410, 415),
#  'field': (411, 507),
#  'job': (412, 64),
#  'titles': (413, 142),
#  'such': (414, 1591),
#  'office': (415, 470),
#  'manager': (416, 254),
#  'executive': (417, 258),
#  'assistant': (418, 208),
#  'there': (419, 1522),
#  '13': (420, 615),
#  'properties': (421, 122),
#  'districts': (422, 182),
#  'listed': (423, 476),
#  'register': (424, 326),
#  '10': (425, 945),
#  '1910': (426, 128),
#  'died': (427, 727),
#  'november': (428, 1164),
#  '1945': (429, 282),
#  'special': (430, 351),
#  'operations': (431, 185),
#  'officer': (432, 317),
#  'danish': (433, 144),
#  'resistance': (434, 64),
#  'fighter': (435, 66),
#  'during': (436, 2308),
#  'second': (437, 1506),
#  'founder': (438, 210),
#  'institute': (439, 476),
#  'molecular': (440, 53),
#  'medicine': (441, 130),
#  'california': (442, 691),
#  'serves': (443, 233),
#  'chief': (444, 342),
#  'scientific': (445, 232),
#  'said': (446, 318),
#  'time': (447, 1657),
#  'out': (448, 907),
#  'very': (449, 515),
#  'before': (450, 1159),
#  'arrived': (451, 67),
#  'night': (452, 202),
#  'joe': (453, 115),
#  'd': (454, 681),
#  'connecticut': (455, 119),
#  'les': (456, 60),
#  'de': (457, 1426),
#  'term': (458, 473),
#  'london': (459, 613),
#  'exist': (460, 95),
#  'networks': (461, 86),
#  'commonly': (462, 328),
#  'so': (463, 546),
#  'named': (464, 1020),
#  'these': (465, 1067),
#  'issues': (466, 196),
#  'edited': (467, 83),
#  'guest': (468, 87),
#  'editor': (469, 208),
#  'plays': (470, 455),
#  'goalkeeper': (471, 68),
#  'technique': (472, 79),
#  'applied': (473, 142),
#  'thousands': (474, 51),
#  'taken': (475, 232),
#  'now': (476, 891),
#  'held': (477, 1113),
#  'northern': (478, 717),
#  'parts': (479, 280),
#  'radio': (480, 621),
#  'station': (481, 1290),
#  '9': (482, 698),
#  'fm': (483, 134),
#  'licensed': (484, 138),
#  'serve': (485, 159),
#  'phoenix': (486, 56),
#  'arizona': (487, 132),
#  'member': (488, 1438),
#  'hall': (489, 420),
#  'fame': (490, 165),
#  'alan': (491, 86),
#  'ray': (492, 94),
#  '30': (493, 636),
#  '1938': (494, 155),
#  'conductor': (495, 57),
#  'grows': (496, 64),
#  'typically': (497, 216),
#  'moist': (498, 62),
#  'soil': (499, 125),
#  'regions': (500, 182),
#  'formed': (501, 460),
#  'part': (502, 1835),
#  'greater': (503, 199),
#  'norwegian': (504, 231),
#  'commonwealth': (505, 115),
#  'lower': (506, 320),
#  'small': (507, 838),
#  'hamlet': (508, 75),
#  '19': (509, 508),
#  'houses': (510, 170),
#  'road': (511, 722),
#  'edge': (512, 117),
#  'wales': (513, 291),
#  'husband': (514, 96),
#  'early': (515, 952),
#  'construction': (516, 261),
#  'covers': (517, 157),
#  '100': (518, 434),
#  'years': (519, 1768),
#  'because': (520, 556),
#  'lack': (521, 105),
#  'resources': (522, 174),
#  'process': (523, 308),
#  'strong': (524, 194),
#  'year': (525, 1478),
#  '1950': (526, 205),
#  'silent': (527, 95),
#  'partner': (528, 86),
#  '2001': (529, 556),
#  'australian': (530, 792),
#  'generated': (531, 63),
#  '11': (532, 658),
#  'albums': (533, 255),
#  'electric': (534, 152),
#  'classical': (535, 154),
#  'guitar': (536, 143),
#  'fell': (537, 71),
#  'short': (538, 457),
#  'long': (539, 630),
#  'goal': (540, 137),
#  'producing': (541, 83),
#  'lifetime': (542, 53),
#  'famous': (543, 313),
#  'works': (544, 571),
#  'include': (545, 820),
#  'sculpture': (546, 66),
#  '1969': (547, 271),
#  'act': (548, 395),
#  'friends': (549, 112),
#  'highest': (550, 260),
#  'form': (551, 593),
#  'art': (552, 584),
#  '1970': (553, 251),
#  'spent': (554, 217),
#  'auckland': (555, 53),
#  'educated': (556, 135),
#  'st': (557, 753),
#  'peter': (558, 274),
#  'college': (559, 1135),
#  'however': (560, 833),
#  'crown': (561, 91),
#  'coach': (562, 470),
#  'both': (563, 1226),
#  'bus': (564, 123),
#  'industry': (565, 303),
#  '1990s': (566, 177),
#  'thomas': (567, 368),
#  'gained': (568, 128),
#  'significant': (569, 257),
#  'ground': (570, 317),
#  'west': (571, 1314),
#  'coast': (572, 399),
#  'once': (573, 310),
#  'discovered': (574, 160),
#  'studied': (575, 238),
#  'physics': (576, 113),
#  'technology': (577, 376),
#  'album': (578, 2003),
#  'released': (579, 1680),
#  '2016': (580, 725),
#  '20th': (581, 186),
#  'anniversary': (582, 79),
#  'raised': (583, 121),
#  'forest': (584, 282),
#  'park': (585, 884),
#  'cemetery': (586, 130),
#  'regional': (587, 405),
#  'health': (588, 381),
#  'services': (589, 419),
#  'northwestern': (590, 93),
#  '1951': (591, 200),
#  '3': (592, 1304),
#  '1989': (593, 336),
#  'painter': (594, 185),
#  'political': (595, 544),
#  'reasons': (596, 73),
#  'according': (597, 559),
#  'charles': (598, 366),
#  'c': (599, 750),
#  'liberal': (600, 175),
#  'place': (601, 881),
#  'own': (602, 427),
#  'effect': (603, 188),
#  'entirely': (604, 67),
#  'apart': (605, 57),
#  'god': (606, 137),
#  'tool': (607, 52),
#  'farmers': (608, 62),
#  'use': (609, 824),
#  'move': (610, 123),
#  'while': (611, 1105),
#  'living': (612, 287),
#  'completed': (613, 263),
#  'pilot': (614, 101),
#  'training': (615, 267),
#  'african': (616, 275),
#  'horse': (617, 130),
#  'judge': (618, 194),
#  '23': (619, 459),
#  '1963': (620, 223),
#  'overall': (621, 247),
#  'championship': (622, 658),
#  'title': (623, 704),
#  '1998': (624, 424),
#  'design': (625, 399),
#  'books': (626, 382),
#  'seen': (627, 234),
#  'renowned': (628, 53),
#  'expert': (629, 72),
#  'international': (630, 1285),
#  'history': (631, 802),
#  'pollution': (632, 79),
#  'produced': (633, 747),
#  'generation': (634, 159),
#  'electricity': (635, 163),
#  'rather': (636, 222),
#  'than': (637, 1325),
#  'site': (638, 502),
#  'same': (639, 805),
#  'used': (640, 1752),
#  'movie': (641, 223),
#  '1942': (642, 220),
#  'actions': (643, 75),
#  'military': (644, 507),
#  'attacks': (645, 64),
#  'prime': (646, 210),
#  'minister': (647, 536),
#  'four': (648, 913),
#  'left': (649, 462),
#  'party': (650, 1025),
#  'june': (651, 1095),
#  '1997': (652, 402),
#  '1915': (653, 118),
#  'although': (654, 584),
#  'usually': (655, 375),
#  'songs': (656, 396),
#  'singing': (657, 72),
#  'recently': (658, 170),
#  'been': (659, 2730),
#  'incorporated': (660, 99),
#  'magazine': (661, 366),
#  'monthly': (662, 57),
#  'print': (663, 58),
#  'digital': (664, 175),
#  'list': (665, 650),
#  'transfer': (666, 89),
#  'find': (667, 115),
#  'users': (668, 83),
#  'married': (669, 351),
#  'television': (670, 961),
#  '1967': (671, 244),
#  'romanian': (672, 70),
#  'later': (673, 1357),
#  'transport': (674, 151),
#  'dead': (675, 106),
#  'retained': (676, 53),
#  'beauty': (677, 54),
#  'technical': (678, 140),
#  'depending': (679, 70),
#  'where': (680, 1529),
#  'michigan': (681, 269),
#  'purchased': (682, 108),
#  'falls': (683, 117),
#  'novel': (684, 392),
#  'increasing': (685, 113),
#  'growth': (686, 147),
#  'los': (687, 345),
#  'angeles': (688, 283),
#  'limited': (689, 232),
#  'ability': (690, 107),
#  'space': (691, 305),
#  'remains': (692, 201),
#  'continuing': (693, 55),
#  'third': (694, 771),
#  'studio': (695, 440),
#  'turkish': (696, 122),
#  'singer': (697, 406),
#  'first': (698, 4217),
#  'july': (699, 1182),
#  '6': (700, 1035),
#  '2004': (701, 654),
#  'all': (702, 1783),
#  'homes': (703, 95),
#  'neighbourhood': (704, 67),
#  'manufactured': (705, 66),
#  'blue': (706, 248),
#  '1996': (707, 444),
#  'documentary': (708, 155),
#  'jane': (709, 61),
#  'teaching': (710, 115),
#  'starring': (711, 278),
#  'simple': (712, 95),
#  'roles': (713, 204),
#  'composed': (714, 251),
#  'carrying': (715, 61),
#  'forward': (716, 132),
#  'active': (717, 314),
#  'social': (718, 477),
#  'less': (719, 316),
#  'frequently': (720, 104),
#  'organizations': (721, 137),
#  'women': (722, 718),
#  'more': (723, 1716),
#  'generally': (724, 258),
#  'engineering': (725, 226),
#  'distinguished': (726, 98),
#  'called': (727, 987),
#  'japanese': (728, 473),
#  'given': (729, 452),
#  'representation': (730, 55),
#  'christ': (731, 75),
#  'head': (732, 519),
#  'albert': (733, 116),
#  'compiled': (734, 62),
#  '5': (735, 1325),
#  'record': (736, 645),
#  'opponents': (737, 51),
#  'brick': (738, 88),
#  'federal': (739, 369),
#  'style': (740, 377),
#  'located': (741, 2110),
#  'town': (742, 1218),
#  'two': (743, 2582),
#  'miles': (744, 228),
#  'km': (745, 1230),
#  '1928': (746, 152),
#  'won': (747, 1354),
#  'bronze': (748, 164),
#  'medal': (749, 400),
#  'competition': (750, 451),
#  'treaty': (751, 75),
#  'came': (752, 365),
#  'agreement': (753, 133),
#  'linked': (754, 62),
#  'strength': (755, 50),
#  'common': (756, 455),
#  'interests': (757, 76),
#  'word': (758, 208),
#  'uss': (759, 79),
#  'class': (760, 395),
#  'submarine': (761, 63),
#  'navy': (762, 411),
#  '1': (763, 1983),
#  'target': (764, 77),
#  'criminal': (765, 98),
#  'sexual': (766, 99),
#  'investigation': (767, 66),
#  'temple': (768, 199),
#  'over': (769, 1647),
#  'owned': (770, 406),
#  'communications': (771, 121),
#  'air': (772, 682),
#  'contemporary': (773, 179),
#  'rich': (774, 83),
#  '1972': (775, 310),
#  'football': (776, 1833),
#  'defensive': (777, 70),
#  'middle': (778, 315),
#  'colleges': (779, 86),
#  'schools': (780, 346),
#  'membership': (781, 93),
#  'further': (782, 331),
#  'decline': (783, 52),
#  '62': (784, 55),
#  'processes': (785, 122),
#  'might': (786, 114),
#  'changes': (787, 217),
#  'caused': (788, 156),
#  'marine': (789, 288),
#  'through': (790, 1261),
#  'impact': (791, 161),
#  'after': (792, 2891),
#  'web': (793, 124),
#  'stations': (794, 199),
#  'around': (795, 758),
#  'followed': (796, 249),
#  'example': (797, 370),
#  'temperature': (798, 203),
#  'specific': (799, 157),
#  'volume': (800, 131),
#  'basin': (801, 91),
#  'km2': (802, 133),
#  'competed': (803, 411),
#  'portugal': (804, 95),
#  'summer': (805, 586),
#  'olympics': (806, 463),
#  'foundation': (807, 261),
#  'leading': (808, 331),
#  'figure': (809, 217),
#  'took': (810, 640),
#  'overseas': (811, 68),
#  'sports': (812, 344),
#  'club': (813, 1129),
#  'seasons': (814, 241),
#  'then': (815, 1162),
#  'tradition': (816, 114),
#  'sometimes': (817, 324),
#  'different': (818, 555),
#  'forms': (819, 252),
#  'belgium': (820, 92),
#  'qualified': (821, 80),
#  '1934': (822, 145),
#  'fifa': (823, 76),
#  'cup': (824, 663),
#  'italy': (825, 326),
#  'they': (826, 2278),
#  'lost': (827, 364),
#  'round': (828, 375),
#  'germany': (829, 552),
#  'buried': (830, 98),
#  'france': (831, 630),
#  'plot': (832, 77),
#  'result': (833, 315),
#  'stood': (834, 72),
#  'presented': (835, 150),
#  'evening': (836, 54),
#  'bbc': (837, 169),
#  'news': (838, 285),
#  'alongside': (839, 123),
#  'francisco': (840, 174),
#  '12': (841, 739),
#  '1949': (842, 202),
#  'spanish': (843, 374),
#  'priest': (844, 95),
#  'catholic': (845, 331),
#  'church': (846, 1018),
#  'personal': (847, 207),
#  'dutch': (848, 255),
#  'physician': (849, 86),
#  'among': (850, 595),
#  'sixth': (851, 181),
#  '6th': (852, 88),
#  '60': (853, 161),
#  'reading': (854, 80),
#  'grade': (855, 137),
#  'level': (856, 504),
#  '39': (857, 64),
#  'skills': (858, 67),
#  'unincorporated': (859, 204),
#  'community': (860, 933),
#  'texas': (861, 372),
#  'andrew': (862, 126),
#  '25': (863, 606),
#  'zealand': (864, 387),
#  'gold': (865, 338),
#  'silver': (866, 214),
#  '2002': (867, 498),
#  'sri': (868, 130),
#  'rugby': (869, 319),
#  'fourth': (870, 359),
#  'tournament': (871, 449),
#  'ii': (872, 666),
#  'led': (873, 521),
#  'tigers': (874, 64),
#  'seconds': (875, 59),
#  '1954': (876, 207),
#  '1955': (877, 192),
#  '17': (878, 579),
#  'basketball': (879, 421),
#  'represented': (880, 405),
#  'southern': (881, 636),
#  'ncaa': (882, 167),
#  'division': (883, 761),
#  '1952': (884, 214),
#  'activist': (885, 106),
#  'advocate': (886, 51),
#  'open': (887, 435),
#  'making': (888, 354),
#  'data': (889, 378),
#  'work': (890, 1087),
#  'control': (891, 340),
#  'board': (892, 389),
#  'appointed': (893, 367),
#  'victorian': (894, 99),
#  'government': (895, 978),
#  'following': (896, 1006),
#  'managed': (897, 168),
#  'rock': (898, 581),
#  'n': (899, 402),
#  'roll': (900, 51),
#  '2': (901, 1561),
#  'uk': (902, 445),
#  '1960s': (903, 169),
#  'degrees': (904, 87),
#  'branch': (905, 202),
#  'december': (906, 1143),
#  '2007': (907, 831),
#  'grown': (908, 55),
#  '150': (909, 93),
#  'global': (910, 483),
#  'businesses': (911, 74),
#  'stars': (912, 237),
#  'play': (913, 519),
#  'socialist': (914, 86),
#  'parliamentary': (915, 99),
#  '1999': (916, 424),
#  'saw': (917, 170),
#  'double': (918, 134),
#  'reached': (919, 277),
#  'number': (920, 1073),
#  'respectively': (921, 118),
#  'stewart': (922, 70),
#  'specialized': (923, 53),
#  'another': (924, 491),
#  'way': (925, 371),
#  'students': (926, 417),
#  'speech': (927, 63),
#  'governor': (928, 270),
#  'expressed': (929, 59),
#  'concern': (930, 69),
#  'about': (931, 1516),
#  'discovery': (932, 84),
#  'moth': (933, 316),
#  '1927': (934, 128),
#  'née': (935, 66),
#  'german': (936, 801),
#  'performances': (937, 126),
#  'weekly': (938, 115),
#  'hosted': (939, 160),
#  'chris': (940, 103),
#  'members': (941, 753),
#  '19th': (942, 197),
#  'century': (943, 859),
#  'main': (944, 696),
#  'newspaper': (945, 220),
#  'upon': (946, 284),
#  'returning': (947, 95),
#  'austria': (948, 110),
#  'worked': (949, 482),
#  'architectural': (950, 80),
#  'found': (951, 914),
#  'habitats': (952, 56),
#  'local': (953, 732),
#  'society': (954, 495),
#  'dance': (955, 171),
#  'duo': (956, 89),
#  'whose': (957, 269),
#  'william': (958, 590),
#  'habitat': (959, 110),
#  'consists': (960, 255),
#  'gallery': (961, 115),
#  'forests': (962, 154),
#  'ranging': (963, 51),
#  '200': (964, 218),
#  'metres': (965, 187),
#  'completely': (966, 59),
#  'carbon': (967, 303),
#  'forming': (968, 75),
#  'channel': (969, 305),
#  'again': (970, 346),
#  'received': (971, 697),
#  '43': (972, 81),
#  'million': (973, 490),
#  'views': (974, 82),
#  'solution': (975, 66),
#  'pictures': (976, 82),
#  'media': (977, 386),
#  'tennis': (978, 159),
#  'tour': (979, 393),
#  'along': (980, 726),
#  'valley': (981, 394),
#  'river': (982, 1125),
#  'copenhagen': (983, 50),
#  'denmark': (984, 160),
#  'southeast': (985, 198),
#  'islands': (986, 299),
#  'graham': (987, 55),
#  'antarctica': (988, 52),
#  'point': (989, 428),
#  'just': (990, 450),
#  'brazilian': (991, 142),
#  'lyrics': (992, 109),
#  'prices': (993, 58),
#  'domestic': (994, 103),
#  'market': (995, 294),
#  'food': (996, 269),
#  'primary': (997, 329),
#  'means': (998, 263),
#  'themselves': (999, 125),
#  ...}

# %%
counter
# Out:
# Counter({'the': 137026,
#          'of': 71072,
#          'in': 62470,
#          'and': 56892,
#          'a': 46819,
#          'is': 32587,
#          'to': 30629,
#          'was': 25498,
#          'as': 16121,
#          'for': 15733,
#          'by': 15433,
#          'on': 14715,
#          'it': 11623,
#          'he': 11619,
#          's': 11499,
#          'with': 11287,
#          'from': 10752,
#          'at': 10288,
#          'an': 9586,
#          'that': 7795,
#          'his': 7236,
#          'are': 5741,
#          'also': 5515,
#          'which': 5475,
#          'or': 5022,
#          'has': 5003,
#          'born': 4337,
#          'its': 4283,
#          'first': 4217,
#          'this': 3964,
#          'one': 3864,
#          'were': 3792,
#          'be': 3718,
#          'who': 3668,
#          'new': 3524,
#          'their': 2971,
#          'american': 2930,
#          'after': 2891,
#          'known': 2869,
#          'district': 2852,
#          'united': 2804,
#          'been': 2730,
#          'have': 2702,
#          'she': 2621,
#          'county': 2619,
#          'national': 2603,
#          'two': 2582,
#          'had': 2563,
#          'but': 2493,
#          'world': 2449,
#          'states': 2395,
#          'not': 2353,
#          'during': 2308,
#          'other': 2300,
#          'they': 2278,
#          'film': 2235,
#          'may': 2225,
#          'school': 2165,
#          'university': 2152,
#          'state': 2145,
#          'located': 2110,
#          'city': 2098,
#          'her': 2054,
#          'south': 2027,
#          'album': 2003,
#          '1': 1983,
#          'between': 1904,
#          'most': 1902,
#          'part': 1835,
#          'football': 1833,
#          'into': 1806,
#          'family': 1801,
#          'season': 1794,
#          'all': 1783,
#          'village': 1769,
#          'years': 1768,
#          'when': 1767,
#          'name': 1763,
#          'played': 1758,
#          'used': 1752,
#          'more': 1716,
#          'series': 1696,
#          'released': 1680,
#          'team': 1663,
#          'time': 1657,
#          'north': 1651,
#          'over': 1647,
#          'such': 1591,
#          'league': 1568,
#          'area': 1563,
#          '2': 1561,
#          'can': 1554,
#          'where': 1529,
#          'only': 1523,
#          'there': 1522,
#          'about': 1516,
#          'second': 1506,
#          'year': 1478,
#          'former': 1456,
#          'some': 1453,
#          'three': 1447,
#          'member': 1438,
#          'de': 1426,
#          'since': 1418,
#          'species': 1414,
#          'under': 1405,
#          'music': 1402,
#          'many': 1402,
#          'including': 1381,
#          'war': 1360,
#          'later': 1357,
#          'won': 1354,
#          'than': 1325,
#          '5': 1325,
#          'west': 1314,
#          '3': 1304,
#          'population': 1299,
#          'group': 1297,
#          'company': 1292,
#          'until': 1291,
#          'station': 1290,
#          'international': 1285,
#          'made': 1278,
#          'through': 1261,
#          'march': 1257,
#          'house': 1255,
#          'british': 1244,
#          'well': 1241,
#          'km': 1230,
#          'both': 1226,
#          'became': 1225,
#          'town': 1218,
#          'september': 1216,
#          'october': 1209,
#          'january': 1207,
#          'people': 1198,
#          'july': 1182,
#          'up': 1181,
#          'based': 1179,
#          'served': 1175,
#          'being': 1173,
#          '4': 1170,
#          'november': 1164,
#          'then': 1162,
#          'several': 1160,
#          'before': 1159,
#          'august': 1153,
#          'high': 1153,
#          'east': 1152,
#          'band': 1150,
#          'december': 1143,
#          'college': 1135,
#          'song': 1133,
#          'april': 1132,
#          'club': 1129,
#          'river': 1125,
#          'held': 1113,
#          'while': 1105,
#          'june': 1095,
#          'work': 1087,
#          'english': 1075,
#          'number': 1073,
#          'these': 1067,
#          'john': 1064,
#          '2006': 1061,
#          '2010': 1060,
#          'province': 1051,
#          'best': 1046,
#          'no': 1035,
#          '6': 1035,
#          'party': 1025,
#          'would': 1022,
#          'named': 1020,
#          'church': 1018,
#          'within': 1008,
#          'following': 1006,
#          'york': 1003,
#          'player': 1000,
#          'i': 999,
#          'u': 988,
#          'called': 987,
#          'game': 982,
#          'central': 981,
#          'government': 978,
#          'february': 975,
#          '2011': 968,
#          'television': 961,
#          'early': 952,
#          '10': 945,
#          'public': 943,
#          'community': 933,
#          'region': 927,
#          'published': 919,
#          'found': 914,
#          'four': 913,
#          'out': 907,
#          'system': 903,
#          'major': 900,
#          '2009': 898,
#          'against': 896,
#          '2008': 896,
#          'now': 891,
#          '2012': 889,
#          '7': 888,
#          'single': 886,
#          'park': 884,
#          'professional': 883,
#          'built': 882,
#          'place': 881,
#          'games': 875,
#          'century': 859,
#          'general': 855,
#          '2015': 850,
#          'french': 844,
#          'home': 841,
#          'small': 838,
#          'however': 833,
#          '2014': 833,
#          '2007': 831,
#          'currently': 827,
#          'use': 824,
#          'include': 820,
#          'water': 817,
#          'island': 813,
#          'm': 811,
#          'president': 808,
#          'same': 805,
#          'history': 802,
#          'each': 802,
#          'german': 801,
#          '8': 801,
#          'australian': 792,
#          'england': 789,
#          'will': 787,
#          'line': 782,
#          '2013': 781,
#          'career': 772,
#          'third': 771,
#          'division': 761,
#          'around': 758,
#          'st': 753,
#          'members': 753,
#          'c': 750,
#          'book': 750,
#          'australia': 750,
#          'him': 748,
#          'produced': 747,
#          'building': 747,
#          'census': 743,
#          '12': 739,
#          'show': 739,
#          'local': 732,
#          '20': 731,
#          'died': 727,
#          'country': 727,
#          'along': 726,
#          '2016': 725,
#          'road': 722,
#          'western': 718,
#          'women': 718,
#          'near': 718,
#          'northern': 717,
#          'founded': 714,
#          'service': 710,
#          'research': 709,
#          'title': 704,
#          'canada': 703,
#          'municipality': 699,
#          '9': 698,
#          'last': 698,
#          '2005': 697,
#          'received': 697,
#          'main': 696,
#          'written': 694,
#          'association': 693,
#          'final': 692,
#          'california': 691,
#          'politician': 689,
#          'power': 687,
#          'air': 682,
#          'd': 681,
#          'them': 680,
#          'india': 680,
#          '15': 676,
#          'large': 672,
#          'historic': 672,
#          'life': 668,
#          'award': 667,
#          'ii': 666,
#          'center': 665,
#          'cup': 663,
#          'energy': 659,
#          'law': 659,
#          'director': 658,
#          '11': 658,
#          'championship': 658,
#          '2004': 654,
#          'development': 653,
#          'list': 650,
#          'record': 645,
#          'due': 644,
#          'council': 643,
#          '14': 643,
#          'canadian': 642,
#          'union': 642,
#          'took': 640,
#          'department': 637,
#          'footballer': 637,
#          '30': 636,
#          'southern': 636,
#          'directed': 634,
#          'army': 631,
#          'long': 630,
#          'france': 630,
#          'established': 628,
#          'often': 626,
#          'end': 626,
#          'radio': 621,
#          '16': 619,
#          'began': 618,
#          'genus': 618,
#          '13': 615,
#          'london': 613,
#          'son': 613,
#          '25': 606,
#          'created': 606,
#          'railway': 606,
#          'street': 601,
#          'day': 601,
#          'top': 598,
#          'event': 597,
#          'five': 596,
#          'among': 595,
#          'set': 595,
#          'form': 593,
#          'william': 590,
#          'death': 590,
#          'men': 589,
#          'summer': 586,
#          '2000': 584,
#          'art': 584,
#          'although': 584,
#          'king': 581,
#          'rock': 581,
#          '18': 581,
#          '17': 579,
#          'included': 577,
#          'times': 574,
#          'lake': 574,
#          'rural': 573,
#          'works': 571,
#          'any': 567,
#          'original': 566,
#          'indian': 564,
#          'sea': 563,
#          'late': 559,
#          'according': 559,
#          'royal': 559,
#          '2003': 558,
#          'because': 556,
#          '2001': 556,
#          'education': 555,
#          'different': 555,
#          'climate': 553,
#          'like': 553,
#          'science': 552,
#          'germany': 552,
#          'china': 547,
#          'so': 546,
#          'political': 544,
#          'originally': 544,
#          'children': 544,
#          'james': 542,
#          'period': 541,
#          'election': 538,
#          'minister': 536,
#          'great': 536,
#          'various': 534,
#          'recorded': 531,
#          'european': 530,
#          'order': 524,
#          'e': 523,
#          'poland': 521,
#          'led': 521,
#          'language': 519,
#          'head': 519,
#          'play': 519,
#          'production': 518,
#          'very': 515,
#          'court': 514,
#          'records': 514,
#          'approximately': 511,
#          '19': 508,
#          'field': 507,
#          'military': 507,
#          'level': 504,
#          'site': 502,
#          'land': 501,
#          'san': 501,
#          'category': 499,
#          '2002': 498,
#          'program': 497,
#          '21': 497,
#          'society': 495,
#          'business': 495,
#          'total': 494,
#          '24': 493,
#          'capital': 493,
#          'another': 491,
#          'million': 490,
#          'role': 489,
#          'back': 488,
#          '27': 488,
#          'america': 487,
#          'eastern': 487,
#          'republic': 486,
#          '28': 485,
#          'age': 484,
#          'writer': 484,
#          'did': 483,
#          'global': 483,
#          'worked': 482,
#          'museum': 478,
#          'social': 477,
#          'debut': 477,
#          'listed': 476,
#          'institute': 476,
#          '22': 476,
#          'term': 473,
#          'japanese': 473,
#          'elected': 472,
#          'professor': 471,
#          'italian': 471,
#          'largest': 471,
#          'live': 471,
#          'if': 471,
#          'japan': 471,
#          'office': 470,
#          'coach': 470,
#          'white': 470,
#          'still': 469,
#          '26': 469,
#          'b': 469,
#          'includes': 468,
#          'ice': 466,
#          'moved': 465,
#          'change': 464,
#          'administrative': 463,
#          'olympics': 463,
#          'events': 462,
#          'left': 462,
#          'kingdom': 462,
#          'actor': 461,
#          'formed': 460,
#          'considered': 460,
#          'black': 459,
#          'popular': 459,
#          '23': 459,
#          'george': 458,
#          'short': 457,
#          'plays': 455,
#          'common': 455,
#          't': 455,
#          'championships': 455,
#          'countries': 455,
#          'having': 455,
#          'artist': 454,
#          'current': 453,
#          'those': 453,
#          'given': 452,
#          'much': 452,
#          'places': 452,
#          'competition': 451,
#          'old': 450,
#          'just': 450,
#          'tournament': 449,
#          'using': 449,
#          'natural': 449,
#          'us': 448,
#          'developed': 448,
#          '1992': 448,
#          'started': 447,
#          'russian': 446,
#          'important': 446,
#          'uk': 445,
#          '1996': 444,
#          'video': 444,
#          'plant': 442,
#          'could': 442,
#          'story': 441,
#          'mountain': 441,
#          'la': 441,
#          'studio': 440,
#          'areas': 440,
#          'side': 440,
#          'author': 436,
#          'open': 435,
#          '100': 434,
#          'playing': 433,
#          'features': 431,
#          'release': 428,
#          'point': 428,
#          'six': 428,
#          'own': 427,
#          'modern': 426,
#          'described': 426,
#          'hockey': 424,
#          '1998': 424,
#          '1999': 424,
#          'centre': 424,
#          'down': 423,
#          'civil': 423,
#          'lies': 422,
#          'see': 421,
#          'basketball': 421,
#          'europe': 420,
#          'hall': 420,
#          'services': 419,
#          'teams': 418,
#          'students': 417,
#          'race': 417,
#          'human': 416,
#          'support': 415,
#          'become': 415,
#          '1994': 414,
#          'designed': 414,
#          'iran': 413,
#          'navy': 411,
#          'competed': 411,
#          'project': 411,
#          'father': 409,
#          'academy': 407,
#          'singer': 406,
#          'owned': 406,
#          'regional': 405,
#          'represented': 405,
#          '1997': 402,
#          'n': 402,
#          'network': 402,
#          'appeared': 402,
#          '1993': 401,
#          'independent': 400,
#          'medal': 400,
#          'coast': 399,
#          'design': 399,
#          'films': 399,
#          '1991': 398,
#          'songs': 396,
#          'david': 396,
#          'do': 396,
#          'act': 395,
#          'class': 395,
#          'valley': 394,
#          '1988': 394,
#          'tour': 393,
#          'force': 393,
#          'novel': 392,
#          'version': 391,
#          'baseball': 391,
#          'washington': 390,
#          'board': 389,
#          'zealand': 387,
#          'media': 386,
#          'route': 386,
#          'previously': 385,
#          'systems': 384,
#          'conference': 384,
#          'went': 384,
#          '1995': 383,
#          'books': 382,
#          'lead': 381,
#          'health': 381,
#          'arts': 380,
#          'assembly': 379,
#          'robert': 379,
#          'data': 378,
#          'awards': 378,
#          'per': 378,
#          'style': 377,
#          'roman': 377,
#          'technology': 376,
#          'tv': 376,
#          'young': 375,
#          'usually': 375,
#          'round': 375,
#          'festival': 375,
#          'red': 375,
#          'spanish': 374,
#          'run': 374,
#          'texas': 372,
#          'parliament': 372,
#          'way': 371,
#          'organization': 371,
#          'example': 370,
#          'federal': 369,
#          'chinese': 369,
#          'africa': 369,
#          'thomas': 368,
#          'retired': 368,
#          '1990': 367,
#          'appointed': 367,
#          '29': 367,
#          'charles': 366,
#          'magazine': 366,
#          'type': 365,
#          'came': 365,
#          'similar': 365,
#          'lost': 364,
#          'management': 364,
#          'bay': 361,
#          'fourth': 359,
#          'committee': 357,
#          'others': 356,
#          'notable': 356,
#          'character': 356,
#          'making': 354,
#          'joined': 354,
#          'together': 354,
#          'virginia': 353,
#          'township': 353,
#          'off': 352,
#          'special': 351,
#          'married': 351,
#          '1987': 351,
#          'information': 351,
#          'next': 351,
#          'what': 350,
#          'track': 350,
#          'opened': 350,
#          '1984': 347,
#          'parish': 347,
#          'working': 346,
#          'schools': 346,
#          'again': 346,
#          'los': 345,
#          '1985': 345,
#          'free': 345,
#          'sports': 344,
#          '31': 344,
#          '1979': 344,
#          'families': 342,
#          'chief': 342,
#          'grand': 341,
#          'position': 341,
#          'light': 340,
#          'control': 340,
#          '1980': 340,
#          'stage': 340,
#          'voivodeship': 339,
#          'gold': 338,
#          'j': 338,
#          'official': 338,
#          'though': 337,
#          'ireland': 337,
#          'few': 337,
#          'studies': 337,
#          '1989': 336,
#          'without': 335,
#          'make': 335,
#          'across': 335,
#          'refer': 332,
#          'private': 332,
#          'further': 331,
#          'leading': 331,
#          'catholic': 331,
#          'michael': 330,
#          'battle': 330,
#          'primary': 329,
#          'range': 329,
#          'bank': 329,
#          'commonly': 328,
#          'native': 328,
#          'register': 326,
#          'italy': 326,
#          'earth': 326,
#          'available': 325,
#          '1983': 325,
#          'paul': 324,
#          'sometimes': 324,
#          'sold': 324,
#          'featured': 323,
#          'leader': 322,
#          'finished': 321,
#          'throughout': 321,
#          'lower': 320,
#          'edition': 320,
#          'man': 320,
#          'rugby': 319,
#          '1982': 319,
#          'said': 318,
#          'even': 317,
#          'officer': 317,
#          'ground': 317,
#          'g': 317,
#          'seven': 317,
#          'less': 316,
#          'moth': 316,
#          'green': 316,
#          '1986': 316,
#          'study': 316,
#          'middle': 315,
#          'result': 315,
#          'active': 314,
#          'l': 314,
#          'star': 314,
#          'famous': 313,
#          '2017': 313,
#          'o': 313,
#          'airport': 313,
#          'musical': 312,
#          'greek': 312,
#          'every': 311,
#          'forces': 311,
#          'once': 310,
#          '1972': 310,
#          'highway': 310,
#          'today': 309,
#          'wife': 309,
#          'process': 308,
#          'singles': 308,
#          'addition': 307,
#          'annual': 307,
#          'model': 307,
#          'above': 306,
#          'space': 305,
#          'channel': 305,
#          '1978': 305,
#          'movement': 304,
#          'drama': 304,
#          'you': 304,
#          'producer': 304,
#          'hill': 304,
#          'label': 304,
#          'spain': 303,
#          'gmina': 303,
#          'industry': 303,
#          'carbon': 303,
#          'wrote': 303,
#          'seat': 303,
#          'bridge': 302,
#          'pennsylvania': 302,
#          '1976': 302,
#          'chart': 301,
#          'actress': 301,
#          'democratic': 301,
#          'awarded': 300,
#          'irish': 300,
#          '1975': 299,
#          'islands': 299,
#          'formerly': 299,
#          'little': 297,
#          'right': 297,
#          'eight': 297,
#          'performed': 297,
#          'days': 297,
#          '1971': 296,
#          '1973': 296,
#          'players': 295,
#          'collection': 295,
#          'market': 294,
#          'mexico': 294,
#          'brother': 294,
#          'cricket': 293,
#          'body': 293,
#          '1974': 292,
#          'champion': 291,
#          'wales': 291,
#          'case': 290,
#          'groups': 290,
#          'operated': 290,
#          'episode': 290,
#          'ten': 289,
#          'marine': 288,
#          'half': 288,
#          'living': 287,
#          'medical': 286,
#          'historical': 285,
#          'news': 285,
#          'police': 284,
#          'upon': 284,
#          'situated': 284,
#          'trade': 284,
#          'big': 284,
#          'oil': 283,
#          'angeles': 283,
#          '1945': 282,
#          'forest': 282,
#          'contains': 282,
#          'action': 281,
#          '1968': 281,
#          'parts': 280,
#          '50': 280,
#          'scottish': 280,
#          '1977': 279,
#          'stadium': 279,
#          'continued': 279,
#          'christian': 279,
#          'returned': 279,
#          'theatre': 278,
#          'starring': 278,
#          'senior': 278,
#          'reached': 277,
#          'how': 276,
#          'related': 276,
#          'plants': 276,
#          'african': 275,
#          'richard': 275,
#          'peter': 274,
#          'announced': 274,
#          'columbia': 274,
#          'buildings': 274,
#          'numerous': 273,
#          'take': 273,
#          'close': 273,
#          'love': 273,
#          'economic': 273,
#          '1981': 272,
#          'commune': 272,
#          'names': 272,
#          'f': 272,
#          'structure': 272,
#          'primarily': 272,
#          'either': 272,
#          '1969': 271,
#          'serving': 271,
#          'commission': 271,
#          'paris': 271,
#          'governor': 270,
#          'michigan': 269,
#          'whose': 269,
#          'food': 269,
#          'v': 269,
#          'henry': 268,
#          'associated': 268,
#          'win': 268,
#          'programs': 267,
#          'training': 267,
#          'base': 267,
#          'referred': 265,
#          'added': 265,
#          'individual': 264,
#          'section': 264,
#          'completed': 263,
#          'means': 263,
#          'unit': 262,
#          'construction': 261,
#          'foundation': 261,
#          'highest': 260,
#          'saint': 260,
#          'runs': 260,
#          'brown': 260,
#          'commercial': 260,
#          'provide': 259,
#          'signed': 259,
#          'romanized': 259,
#          'post': 259,
#          'daughter': 258,
#          'executive': 258,
#          'generally': 258,
#          'r': 258,
#          'rights': 258,
#          'significant': 257,
#          'carolina': 257,
#          'h': 256,
#          'policy': 255,
#          'albums': 255,
#          'dutch': 255,
#          'consists': 255,
#          'match': 255,
#          'property': 255,
#          '1960': 255,
#          'software': 255,
#          'success': 254,
#          'manager': 254,
#          'least': 254,
#          'nations': 254,
#          'ontario': 254,
#          'previous': 254,
#          'low': 254,
#          'present': 253,
#          'feature': 252,
#          'hospital': 252,
#          'forms': 252,
#          'mi': 252,
#          'sound': 252,
#          'involved': 252,
#          'winning': 252,
#          'mainly': 251,
#          'hit': 251,
#          '1970': 251,
#          'composed': 251,
#          'florida': 251,
#          'soviet': 251,
#          'ocean': 250,
#          'replaced': 250,
#          'followed': 249,
#          'scotland': 249,
#          'mark': 249,
#          'computer': 248,
#          'blue': 248,
#          'shows': 248,
#          'culture': 248,
#          'overall': 247,
#          '1965': 247,
#          'ship': 246,
#          'remained': 245,
#          'p': 245,
#          'ohio': 245,
#          '1967': 244,
#          'points': 244,
#          'degree': 244,
#          'full': 244,
#          'successful': 244,
#          'matches': 244,
#          'surface': 243,
#          'does': 243,
#          'especially': 242,
#          'bishop': 242,
#          'should': 242,
#          'performance': 242,
#          '1964': 242,
#          'good': 242,
#          'environmental': 242,
#          'artists': 241,
#          'seasons': 241,
#          'prior': 241,
#          'sir': 240,
#          'russia': 240,
#          'illinois': 239,
#          'joseph': 239,
#          '1966': 239,
#          '1962': 239,
#          'swedish': 239,
#          'variety': 239,
#          'broadcast': 239,
#          'studied': 238,
#          'stars': 237,
#          'standard': 237,
#          'edward': 237,
#          'jersey': 237,
#          'nuclear': 237,
#          'traditional': 237,
#          'secretary': 235,
#          'female': 235,
#          'products': 234,
#          'seen': 234,
#          'we': 234,
#          'aircraft': 234,
#          'pacific': 234,
#          'serves': 233,
#          'running': 233,
#          'average': 233,
#          '40': 232,
#          'scientific': 232,
#          'taken': 232,
#          'limited': 232,
#          'empire': 232,
#          'higher': 231,
#          'norwegian': 231,
#          'composer': 231,
#          'launched': 230,
#          '1956': 230,
#          'recording': 229,
#          'settlement': 229,
#          'provides': 229,
#          'congress': 228,
#          'source': 228,
#          'miles': 228,
#          'mary': 228,
#          'car': 228,
#          'emissions': 228,
#          'meaning': 227,
#          'via': 227,
#          '1946': 227,
#          'provided': 227,
#          'corporation': 227,
#          'engineering': 226,
#          'fire': 225,
#          'date': 225,
#          'racing': 225,
#          'chicago': 225,
#          'ancient': 224,
#          'real': 224,
#          'minor': 224,
#          'introduced': 224,
#          'almost': 223,
#          '1963': 223,
#          'movie': 223,
#          'soccer': 223,
#          '1947': 223,
#          'away': 223,
#          'eventually': 222,
#          'rather': 222,
#          'olympic': 222,
#          'thus': 222,
#          'dr': 222,
#          'gas': 222,
#          'himself': 222,
#          'despite': 221,
#          'poet': 221,
#          ...})

# %%
5*5*16
# Out:
# 400
